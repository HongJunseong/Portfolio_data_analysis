# %% [markdown]
# ### **"비만", "비만 관련 질병" 이라는 키워드로 네이버 검색 엔진에서 크롤링한 결과**

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = "https://search.naver.com/search.naver"

data_1 = []

for i in range(0,9):
    start_num = i * 15 + 1  # 각 페이지의 시작점 계산 - 네이버에서는 페이지를 넘어갈 때 마다 나타내는 수가 15씩 증가하는 걸로 확인하였다.
    params = {
        'where': 'web',
        'query': '비만',  # 검색어 설정
        'start': start_num  # 페이지 시작점
    }
    req = requests.get(url, params)
    if req.encoding != 'UTF-8' and req.encoding != 'EUC-KR':
                req.encoding = 'UTF-8'

    soup = BeautifulSoup(req.text, 'html.parser')
    
    news_link = soup.find_all('a', class_='link_tit')    
    
    for link in news_link:
        title = link.text
        n_url = link.get('href')
        print(title, n_url)

        try:
            new_req = requests.get(n_url)
            n_soup = BeautifulSoup(new_req.text, 'html.parser')
        
            content = n_soup.get_text()
            keywords = re.findall(r"비만[^\.]*?(?:원인|요인|결과|영향|유발|중요|있습니다|질병|이다|니다)[^\.]*\.",content)

            for keyword in keywords:
                data_1.append([title, n_url, keyword])
                
        except:
            continue
# Out:
# 비만 | 질환백과 | 의료정보 | 건강정보 | 서울아산병원 https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31809
# 비만 - 나무위키 https://namu.wiki/w/%EB%B9%84%EB%A7%8C
# 비만 - 영양 장애 - MSD 매뉴얼 - 일반인용 https://www.msdmanuals.com/ko/home/%EC%98%81%EC%96%91-%EC%9E%A5%EC%95%A0/%EB%B9%84%EB%A7%8C%EA%B3%BC-%EB%8C%80%EC%82%AC-%EC%A6%9D%ED%9B%84%EA%B5%B0/%EB%B9%84%EB%A7%8C
# 비만의 6가지 유형과 원인 - 건강을 위한 발걸음 https://steptohealth.co.kr/6-obesity-and-their-causes/
# 비만이란? https://www.novonordisk.co.kr/patient/obesity-treatment-products/define-baseline.html
# 주간 감염병 최신 정보 5권 37호 ('20.9.14) - 소식지 - 삼성서울병원 http://www.samsunghospital.com/home/info/letterView.do?SEQ=196
# 소아 비만 | 국가건강정보포털 | 질병관리청 https://health.kdca.go.kr/healthinfo/biz/health/gnrlzHealthInfo/gnrlzHealthInfo/gnrlzHealthInfoView.do?cntnts_sn=4008
# 비만 세포 - 위키백과 한국어 https://ko.wikipedia.org/wiki/%EB%B9%84%EB%A7%8C_%EC%84%B8%ED%8F%AC
# 비만증 - 위키백과 한국어 https://ko.wikipedia.org/wiki/%EB%B9%84%EB%A7%8C%EC%A6%9D
# 비만 | 국가건강정보포털 | 질병관리청 https://health.kdca.go.kr/healthinfo/biz/health/gnrlzHealthInfo/gnrlzHealthInfo/gnrlzHealthInfoView.do?cntnts_sn=5292
# 비만은 질병이다, ‘만성질환의 씨앗’ 비만 다스리기 - 당신의 건강가이드 헬스조선 https://health.chosun.com/site/data/html_dir/2016/06/13/2016061301044.html
# 비만 | 의학정보 | 진료안내 | 가정의학과 | 서울아산병원 https://www.amc.seoul.kr/asan/depts/fm/K/bbsDetail.do?menuId=378&contentId=248826
# 비만의 진단과 평가 - 대한비만학회 https://general.kosso.or.kr/html/?pmode=obesityDiagnosis
# 비만 https://www.novonordisk.co.kr/disease-areas/obesity.html
# 세 살 비만 여든까지…체질량 지수 관리해 키 성장 도와야｜동아일보 https://www.donga.com/news/article/all/20240109/122965100/1
# 비만 | 국민건강지식센터 http://hqcenter.snu.ac.kr/archives/jiphyunjeon/%EB%B9%84%EB%A7%8C-4
# 비만증 - 위키백과 한국어 https://ko.wikipedia.org/wiki/%EB%B9%84%EB%A7%8C%EC%A6%9D?wprov=srpw1_0
# 비만 - 하이닥 https://www.hidoc.co.kr/integratesearch/searchresultlist?query=%EB%B9%84%EB%A7%8C
# 세계 비만 관리 비상…2030년 10억명 넘는다 https://www.hani.co.kr/arti/science/future/1034859.html
# 비만율 - 국가발전지표 https://www.index.go.kr/unify/idx-info.do?idxCd=4239
# 분류:비만 - 나무위키 https://namu.wiki/w/%EB%B6%84%EB%A5%98:%EB%B9%84%EB%A7%8C
# 비만 - 송파구 보건소 - 송파구청 https://www.songpa.go.kr/ehealth/contents.do?key=4665
# 비만 | 사랑의병원 https://www.lcc.co.kr/content/sub4_1_1
# 美 비만치료제 관련주 강세…韓 테마주에 외국인은 펩트론, 유한양행 '매수' 큐라티스, 한국비엔씨 '매도' < 증권.... https://www.pointdaily.co.kr/news/articleView.html?idxno=190252
# 비만과 감정 사이의 관계는 무엇일까? - Wonderful Mind https://wonderfulmind.co.kr/relationship-emotions-obesity/
# 비만 | 춘천시보건소 - 춘천시청 https://www.chuncheon.go.kr/health/health-info/obesity/
# 비만 | 뇌졸중 예방 | 뇌졸중 정보 | 뇌졸중센터 | 서울아산병원 https://www.amc.seoul.kr/asan/depts/stroke/K/content.do?menuId=2194
# 5 명 중 1명은 비만으로 조기사망 합니다. https://korean.mercola.com/sites/articles/archive/2017/01/18/%EB%B9%84%EB%A7%8C-%EC%82%AC%EB%A7%9D-%EC%9C%84%ED%97%98.aspx
# 비만이 뇌에 미치는 영향 https://korean.mercola.com/sites/articles/archive/2019/06/16/%EB%B9%84%EB%A7%8C%EC%9D%B4-%EB%87%8C%EC%97%90-%EB%AF%B8%EC%B9%98%EB%8A%94-%EC%98%81%ED%96%A5.aspx
# 비만인 경우 몸에서 어떤 일이 일어날까요? 항상 알 수 있는 것은 아닌 비만의 영향 https://korean.mercola.com/sites/articles/archive/2021/08/08/%EB%B9%84%EB%A7%8C.aspx
# 비만도계산 | 보건소 - 합천군청 https://www.hc.go.kr/06242/06320/06334.web
# 비만으로 가는 지름길, 비만의 다양한 원인 - 건강한 체중 - 삼성서울병원 http://www.samsunghospital.com/home/healthInfo/content/contenView.do?CONT_SRC_ID=27960&CONT_SRC=HOMEPAGE&CONT_ID=3661&CONT_CLS_CD=001021005002
# 마른 그녀…비만이라니요? 마른 비만의 진실 - 건강한 체중 - 삼성서울병원 http://www.samsunghospital.com/home/healthInfo/content/contenView.do?CONT_SRC_ID=30745&CONT_SRC=HOMEPAGE&CONT_ID=4315&CONT_CLS_CD=001021005002
# 비만 - 가족 평생 주치의, 함소아한의원 http://www.hamsoa.com/regist/subject/obesity.asp
# 비만 < 가정의학과 < 건강정보 < 서북병원 https://sbhosp.seoul.go.kr/archives/375
# 비만 PNG 일러스트 | 이미지 및 PSD 파일 | Pngtree에 무료 다운로드 https://kor.pngtree.com/so/%EB%B9%84%EB%A7%8C
# 복부비만 - 나무위키 https://namu.wiki/w/%EB%B3%B5%EB%B6%80%EB%B9%84%EB%A7%8C
# 대사증후군 | 국가건강정보포털 | 질병관리청 https://health.kdca.go.kr/healthinfo/biz/health
- 대한비만학회 https://general.kosso.or.kr/html/?pmode=BBBS0001300003
# 대한비만학회 http://general.kosso.or.kr/
# 비만 | 질환백과 | 의료정보 | 건강정보 | 서울아산병원 https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31809&tabIndex=6
# 비만 | 황성수힐링스쿨 https://healingschool.kr/tag/%EB%B9%84%EB%A7%8C
# 비만(Obesity ) - 영양팀 | 삼성서울병원 http://www.samsunghospital.com/dept/medical/dietarySub01.do?DP_CODE=DD2&MENU_ID=002049&ds_code=D0001509
# "비만 근본 원인은 신진대사…맞춤 치료 특성 살려 한의학적 비만 치료 발전시킬 것" > 뉴스 | 한의신문 https://www.akomnews.com/bbs/board.php?bo_table=news&wr_id=26542
# 비만 - 김현수한의원 http://www.hanione.kr/%EB%B9%84%EB%A7%8C
# 비만 | 수성구청 보건소 https://www.suseong.kr/health/index.do?menu_id=00000920
# 비만/목록 - 나무위키 https://namu.wiki/w/%EB%B9%84%EB%A7%8C/%EB%AA%A9%EB%A1%9D
# 비만진료지침 - 대한비만학회 https://general.kosso.or.kr/html/?pmode=BBBS0001300003
# 대한비만학회 http://general.kosso.or.kr/
# 비만 | 질환백과 | 의료정보 | 건강정보 | 서울아산병원 https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31809&tabIndex=6
# 비만 | 황성수힐링스쿨 https://healingschool.kr/tag/%EB%B9%84%EB%A7%8C
# 비만(Obesity ) - 영양팀 | 삼성서울병원 http://www.samsunghospital.com/dept/medical/dietarySub01.do?DP_CODE=DD2&MENU_ID=002049&ds_code=D0001509
# "비만 근본 원인은 신진대사…맞춤 치료 특성 살려 한의학적 비만 치료 발전시킬 것" > 뉴스 | 한의신문 https://www.akomnews.com/bbs/board.php?bo_table=news&wr_id=26542
# 비만 인구 2억명 시대…게임체인저 'GLP-1' 기전 국산 비만약 개발은? https://medigatenews.com/news/1313733506
# 과체중 → 비만 전 단계 등 한국형 비만 진단 기준 변경 https://www.hidoc.co.kr/healthstory/news/C0000374264
# 비만도 계산기. BMI, 체지방, 칼로리 계산기 - 다이어트로그 http://www.dietlog.kr/s/%EB%B9%84%EB%A7%8C%EB%8F%84%EA%B3%84%EC%82%B0%EA%B8%B0
# 비만 - 고려수지침 파주지회 http://www.soojichim.net/Treat/biman.htm
# 고도비만 - 나무위키 https://namu.wiki/w/%EA%B3%A0%EB%8F%84%EB%B9%84%EB%A7%8C
# 비만 | 보건소 - 진주시청 https://www.jinju.go.kr/05895/06069/06083.web
# 비만진료지침 - 대한비만학회 https://general.kosso.or.kr/html/?pmode=BBBS0001300003
# 대한비만학회 http://general.kosso.or.kr/
# 비만 | 질환백과 | 의료정보 | 건강정보 | 서울아산병원 https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31809&tabIndex=6
# 비만 | 황성수힐링스쿨 https://healingschool.kr/tag/%EB%B9%84%EB%A7%8C
# 비만(Obesity ) - 영양팀 | 삼성서울병원 http://www.samsunghospital.com/dept/medical/dietarySub01.do?DP_CODE=DD2&MENU_ID=002049&ds_code=D0001509
# "비만 근본 원인은 신진대사…맞춤 치료 특성 살려 한의학적 비만 치료 발전시킬 것" > 뉴스 | 한의신문 https://www.akomnews.com/bbs/board.php?bo_table=news&wr_id=26542
- 대한비만학회 https://general.kosso.or.kr/html/?pmode=exerciseObesity
# 비만 - 부평열린내과 http://www.openim.co.kr/Module/CMS/CMS.asp?Srno=32570
# 비만 - 수원 대동내과의원 홈페이지 http://www.d2clinic.com/Module/CMS/CMS.asp?Srno=19997
# 비만 - 청라의원 http://cheongnaclinic.co.kr/Module/CMS/CMS.asp?Srno=24857
# 고도비만 지방흡입 가능한 청담명작의원 https://bodyline24.tistory.com/260
# 비만 고양이 운동법 및 용품 알아보기 – 비마이펫 라이프 https://mypetlife.co.kr/20853/

# %% [markdown]
# ----
# "비만"이라는 키워드로 네이버 검색 엔진에서 검색했을 때 나온 결과들 중에서 link_tit이라는 class를 가진 링크들을 크롤링하여 해당 링크의 title, URL, text 등을 획득하였다.
#
# 비만이라는 단어가 포함된 문장이 필요한 정보를 담고 있는 문장일 것이라고 판단하였다.<br>
# text에서 필요한 정보만을 얻기 위해, 정규표현식을 이용하여, 비만이라는 단어를 포함하는 문장들만 추출하였다.
#
# ----

# %%
from konlpy.tag import Okt
from collections import Counter

# 질병 이름 목록 (예시, 실제 목록은 더 포괄적일 수 있음)
disease_names = [
    "비만", "당뇨병", "고혈압", "심장병", "뇌졸중", "암", "관절염", "간경변", "고지혈증", "우울증", 
    "불면증", "천식", "폐렴", "치매", "골다공증", "위염", "신부전", "간암", "위암", "대장암"
]

df = pd.DataFrame(data_1, columns=['Title', 'URL', 'Sentence'])

# df.to_excel('obesity_related_diseases_data.xlsx', index=False) 
# 위 코드로 크롤링 결과를 excel로 저장할 수 있다.

okt = Okt()
all_sentences = ' '.join(df['Sentence'])
nouns = okt.nouns(all_sentences)

# 불용어 제거
stop_words = ['관련', '질병', '유발', '야기']
nouns = [word for word in nouns if (word not in stop_words) and (word in disease_names)]

# 빈도수 계산
counter = Counter(nouns)
most_common_words = counter.most_common()

# 결과 출력
print("가장 많이 언급된 질병:")
for word, freq in most_common_words:
    if freq >= 5:
        print(f"{word}: {freq}회")
    else:
        pass
# Out:
# 가장 많이 언급된 질병:
# 비만: 2696회
# 당뇨병: 113회
# 고혈압: 92회
# 치매: 42회
# 뇌졸중: 26회
# 관절염: 24회
# 우울증: 24회
# 고지혈증: 21회
# 암: 20회
# 천식: 14회
# 골다공증: 9회
# 폐렴: 7회
# 심장병: 6회

# %% [markdown]
# ----
# 잘 알려진 질병의 이름을 담은 리스트를 직접 생성하였다.<br>
# "비만"이라는 키워드로 검색했을 때 나온 링크를 크롤링하여 추출한 문장들에서, 해당 리스트에 있는 질병들이 얼마나 빈번하게 언급되었는지 출력하는 코드이다.
#
# 검색 키워드인 비만을 제외하면, 당뇨병, 고혈압, 치매, 뇌졸중 등이 가장 빈번하게 나타났음을 알 수 있다.
#
# ----

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

url = "https://search.naver.com/search.naver"

data_2 = []

for i in range(0,9):
    start_num = i * 15 + 1  # 각 페이지의 시작점 계산 - 네이버에서는 페이지를 넘어갈 때 마다 나타내는 수가 15씩 증가하는 걸로 확인하였다.
    params = {
        'where': 'web',
        'query': '비만+관련+질병',  # 검색어 설정
        'start': start_num  # 페이지 시작점
    }
    req = requests.get(url, params)
    if req.encoding != 'UTF-8' and req.encoding != 'EUC-KR':
                req.encoding = 'UTF-8'

    soup = BeautifulSoup(req.text, 'html.parser')

    news_link = soup.find_all('a', class_='link_tit')
    
    for link in news_link:
        title = link.text
        n_url = link.get('href')
        print(title, n_url)

        try:
            new_req = requests.get(n_url)
            n_soup = BeautifulSoup(new_req.text, 'html.parser')
        
            content = n_soup.get_text()
            keywords = re.findall(r"비만[^\.]*?(?:유발|야기)[^\.]*\.",content)


            for keyword in keywords:
                data_2.append([title, n_url, keyword])
                
        except:
            continue
# Out:
# 비만 - 나무위키 https://namu.wiki/w/%EB%B9%84%EB%A7%8C
# 비만 | 질환백과 | 의료정보 | 건강정보 | 서울아산병원 https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31809
# 비만의 동반질환 - 대한비만학회 https://general.kosso.or.kr/html/?pmode=obesityDisease
# 소아 비만과 관련한 질병 8가지 - 건강을 위한 발걸음 https://steptohealth.co.kr/8-diseases-related-to-childhood-obesity/
# 강아지 비만도 표준 기준 관련 질병 https://blog.naver.com/kkh5981/223308955494
# 비만 | 국가건강정보포털 | 질병관리청 https://health.kdca.go.kr/healthinfo/biz/health/gnrlzHealthInfo/gnrlzHealthInfo/gnrlzHealthInfoView.do?cntnts_sn=5292
# "흡연·비만, 류마티스관절염 질병 활성도와 관련 없어" < 소화기/류마티스 < 학술 < 기사본문 - 메디칼업저버 http://www.monews.co.kr/news/articleView.html?idxno=214769
# 비만은 질병이다, ‘만성질환의 씨앗’ 비만 다스리기 - 당신의 건강가이드 헬스조선 https://health.chosun.com/site/data/html_dir/2016/06/13/2016061301044.html
# 다이어트 필수 정보 !! 비만의 원인과 관련 질병 https://ben-jh-family-history.tistory.com/entry/%EB%B9%84%EB%A7%8C%EC%9D%B4-%EC%9B%90%EC%9D%B8%EC%9D%B4-%EB%90%98%EB%8A%94-%EC%97%AC%EB%9F%AC%EA%B0%80%EC%A7%80-%EC%A7%88%EB%B3%91%EB%93%A4%EA%B3%BC-%EC%A7%80%EB%B0%A9%EC%9D%98-%EC%A2%85%EB%A5%98-3%EA%B0%80%EC%A7%80
# 비만에 따른 질병 https://blog.naver.com/jungkuk0/223209516277
# 복부비만율 관련 질병과 치료 https://blog.naver.com/makgulri1004/223268908592
# 소아 비만의 문제와 관련 질병 https://sanson.tistory.com/620
# 비만 < 관련질병 < 가정의학과 < 진료과/의료진 < 진료안내 < 서울의료원 https://www.seoulmc.or.kr/pms/contents/contents.do?contseqn=414&decorator=pmsweb&menucdv=01012204&departmentCode=FM
# 살찌면 위험한 이유(비만 관련 질병) | 남정네 건강칼럼 https://devilofgold.com/%EC%82%B4%EC%B0%8C%EB%A9%B4-%EC%9C%84%ED%97%98%ED%95%9C-%EC%9D%B4%EC%9C%A0%EB%B9%84%EB%A7%8C-%EA%B4%80%EB%A0%A8-%EC%A7%88%EB%B3%91/
# 코로나19 이후 비만·신체활동 관련 지표 악화…신체활동 실천율↓, 비만율↑ < 사회 < 기사본문 - 데일리 이코노.... http://www.enewstoday.kr/news/articleView.html?idxno=14959
# 비만이 질병 및 만병 근원의 원인인 이유(+수명 단축) https://cigarette90.tistory.com/248
://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=32084
# 비만 자체가 질병…비만교육-상담-치료에도 건강보험 적용해야 | 한국경제 https://www.hankyung.com/article/202206054154Y
# 비만도 질병… 식이조절-운동만으론 합병증 관리 어려워｜동아일보 https://www.donga.com/news/article/all/20220823/115098475/1
# 국민 80% 동의해도 질병 인정 못 받는 비만? - 코메디닷컴 https://kormedi.com/1670186/%EA%B5%AD%EB%AF%BC-80-%EB%8F%99%EC%9D%98%ED%95%B4%EB%8F%84-%EC%A7%88%EB%B3%91-%EC%9D%B8%EC%A0%95-%EB%AA%BB-%EB%B0%9B%EB%8A%94-%EB%B9%84%EB%A7%8C/
# [약업신문]비만도 질병...급여 적용해 치료 접근성 높여야 http://www.yakup.com/news/index.html?mode=view&nid=285704
# 대구·경북 청소년 체중분포 및 비만 관련 특성 분석 결과 - 질병관리청 https://www.kdca.go.kr/filepath/boardDownload.es?bid=0034&list_no=718618&seq=1

# %% [markdown]
# ----
# "비만 관련 질병" 이라는 키워드로 네이버 검색 엔진에서 검색했을 때 나온 결과들 중에서, link_tit이라는 class를 가진 링크들을 크롤링하여 해당 링크의 title, URL, text 등을 획득하였다.
#
# 마찬가지로, text에서 필요한 정보만을 얻기 위해 정규표현식을 이용하여, 비만이라는 단어를 포함하는 문장들만 추출하였다.
#
# ----

# %%
from konlpy.tag import Okt
from collections import Counter

# 질병 이름 목록 (예시, 실제 목록은 더 포괄적일 수 있음)
disease_names = [
    "비만", "당뇨병", "고혈압", "심장병", "뇌졸중", "암", "관절염", "간경변", "고지혈증", "우울증", 
    "불면증", "천식", "폐렴", "치매", "골다공증", "위염", "신부전", "간암", "위암", "대장암"
]

df = pd.DataFrame(data_2, columns=['Title', 'URL', 'Sentence'])

# df.to_excel('obesity_related_diseases_data_2.xlsx', index=False) 
# 위 코드로 크롤링 결과를 excel로 저장할 수 있다.

okt = Okt()
all_sentences = ' '.join(df['Sentence'])
nouns = okt.nouns(all_sentences)

# 불용어 제거
stop_words = ['관련', '질병', '유발', '야기']
nouns = [word for word in nouns if (word not in stop_words) and (word in disease_names)]

# 빈도수 계산
counter = Counter(nouns)
most_common_words = counter.most_common()

# 결과 출력
print("가장 많이 나온 질병:")
for word, freq in most_common_words:
    if freq >= 5: # 5번 이상 나온 단어만 출력하였다.
        print(f"{word}: {freq}회")
    else:
        pass
# Out:
# 가장 많이 나온 질병:
# 비만: 200회
# 당뇨병: 19회
# 고혈압: 17회
# 암: 15회
# 고지혈증: 15회

# %% [markdown]
# ----
# "비만 관련 질병"이라는 키워드로 검색했을 때 나온 링크를 크롤링하여 추출한 문장들에서, 해당 리스트에 있는 질병들이 얼마나 빈번하게 언급되었는지 출력하는 코드이다.
#
# 해당 키워드로 크롤링한 결과, 비만을 제외하면 당뇨병, 암, 고혈압, 고지혈증 등이 가장 빈번하게 언급된 것을 확인할 수 있다. 이 중, 암은 비만 외에도 다양한 원인으로 발병하기 때문에 비만과의 관련성을 단독으로 분석하기에는 어려움이 있다. 따라서, 두 크롤링 결과에서 공통적으로 빈번하게 언급된 질병인 당뇨병, 고혈압, 고지혈증에 대한 분석을 진행하고자 한다.
#
# ----
